# %%
print("hello")
# Out:
# hello

# %%
print("ali")
# Out:
# ali

# %%
name = input("Enter name:")
# Out:
# Enter name: ali

# %%
age = int(input("Enter age:"))
# Out:
# Enter age: 16

# %%
if age>=18:
       print("is an adult")
else:
    print("is not an adult")
# Out:
# is not an adult
